# %% [markdown]
# # Creating a Cellular Compartment Reference for OmicsIntegrator2

# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import defaultdict

def flatten(list_of_lists): return [item for sublist in list_of_lists for item in sublist]

import mygene

# %%
genes = pd.read_csv('../../GONN/GO/cellular_component.csv')
genes.head()
# Out:
#   GeneSymbol       GO_ID                       GO_term Evidence
# 0       A1BG  GO:0005576          extracellular region      HDA
# 1       A1BG  GO:0005576          extracellular region      IDA
# 2       A1BG  GO:0005576          extracellular region      TAS
# 3       A1BG  GO:0005615           extracellular space      HDA
# 4       A1BG  GO:0031093  platelet alpha granule lumen      TAS

# %% [markdown]
# ## I. Evidence Codes
#
# Copied from http://geneontology.org/page/guide-go-evidence-codes
#
# ### Experimental Evidence codes
# Use of an experimental evidence code in a GO annotation indicates that the cited paper displayed results from a physical characterization of a gene or gene product that has supported the association of a GO term. The Experimental Evidence codes are:
#
# - Inferred from Experiment (EXP)
# - Inferred from Direct Assay (IDA)
# - Inferred from Physical Interaction (IPI)
# - Inferred from Mutant Phenotype (IMP)
# - Inferred from Genetic Interaction (IGI)
# - Inferred from Expression Pattern (IEP)
#
# ### High Throughput (HTP) evidence codes
# High throughput (HTP) evidence codes may be used to make annotations based upon high throughput methodologies. Use of HTP evidence codes should be carefully considered and follow the GOC's guidelines for their use. The High Throughput Evidence Codes are:
#
# - Inferred from High Throughput Experiment (HTP)
# - Inferred from High Throughput Direct Assay (HDA)
# - Inferred from Hight Throughput Mutant Phenotype (HMP)
# - Inferred from High Throughput Genetic Interaction (HGI)
# - Inferred from High Throughput Expression Pattern (HEP)
#
# ### Computational Analysis evidence codes
# Use of the computational analysis evidence codes indicates that the annotation is based on an in silico analysis of the gene sequence and/or other data as described in the cited reference. The evidence codes in this category also indicate a varying degree of curatorial input. The Computational Analysis evidence codes are:
#
# - Inferred from Sequence or structural Similarity (ISS)
# - Inferred from Sequence Orthology (ISO)
# - Inferred from Sequence Alignment (ISA)
# - Inferred from Sequence Model (ISM)
# - Inferred from Genomic Context (IGC)
# - Inferred from Biological aspect of Ancestor (IBA)
# - Inferred from Biological aspect of Descendant (IBD)
# - Inferred from Key Residues (IKR)
# - Inferred from Rapid Divergence (IRD)
# - Inferred from Reviewed Computational Analysis (RCA)
#
# ### Author statement evidence codes
# Author statement codes indicate that the annotation was made on the basis of a statement made by the author(s) in the reference cited. The Author Statement evidence codes are:
#
# - Traceable Author Statement (TAS)
# - Non-traceable Author Statement (NAS)
#
# ### Curator statement evidence codes
# Use of the curatorial statement evidence codes indicates an annotation made on the basis of a curatorial judgement that does not fit into one of the other evidence code classifications. The Curatorial Statement codes:
#
# - Inferred by Curator (IC)
# - No biological Data available (ND)
#
# ### Electronic Annotation evidence code
# All of the above evidence codes are assigned by curators. However, GO also uses one evidence code that is assigned by automated methods, without curatorial judgement. The Automatically-Assigned evidence code is
#
# - Inferred from Electronic Annotation (IEA)

# %%
solid_codes = ['EXP','IDA','IPI','IMP','IGI','IEP','TAS','NAS']
sketchy_codes = ['HTP','HDA','HMP','HGI','HEP','IC']
bad_codes = ['ISS','ISO','ISA','ISM','IGC','IBA','IBD','IKR','IRD','RCA','IEA','ND']
             
{'solid': len(genes[genes['Evidence'].isin(solid_codes)]), 'sketchy': len(genes[genes['Evidence'].isin(sketchy_codes)]), 'bad': len(genes[genes['Evidence'].isin(bad_codes)])}
# Out:
# {'bad': 39755, 'sketchy': 6061, 'solid': 44651}

# %% [markdown]
# ## II. Find good ontology depth

# %%
g = nx.read_gpickle('../../GONN/GO/GO_cellular_component.pickle')
g

# %%
df = pd.DataFrame.from_dict(dict(g.nodes(data=True))).transpose()
df.head()
# Out:
#            depth                                         name  \
# GO:0000015     3            phosphopyruvate hydratase complex
# GO:0000109     3           nucleotide-excision repair complex
# GO:0000110     4  nucleotide-excision repair factor 1 complex
# GO:0000111     4  nucleotide-excision repair factor 2 complex
# GO:0000112     4  nucleotide-excision repair factor 3 complex
#
#                      namespace
# GO:0000015  cellular_component
# GO:0000109  cellular_component
# GO:0000110  cellular_component
# GO:0000111  cellular_component
# GO:0000112  cellular_component

# %%
df[df.depth == 0]
# Out:
#            depth                name           namespace
# GO:0005575     0  cellular_component  cellular_component

# %%
df[df.depth == 1]
# Out:
#            depth                                       name  \
# GO:0005576     1                       extracellular region
# GO:0005623     1                                       cell
# GO:0009295     1                                   nucleoid
# GO:0016020     1                                   membrane
# GO:0019012     1                                     virion
# GO:0030054     1                              cell junction
# GO:0031974     1                    membrane-enclosed lumen
# GO:0032991     1                 protein-containing complex
# GO:0043226     1                                  organelle
# GO:0044215     1                             other organism
# GO:0044217     1                        other organism part
# GO:0044421     1                  extracellular region part
# GO:0044422     1                             organelle part
# GO:0044423     1                                virion part
# GO:0044425     1                              membrane part
# GO:0044456     1                               synapse part
# GO:0044464     1                                  cell part
# GO:0045202     1                                    synapse
# GO:0055044     1                                   symplast
# GO:0097423     1  mitochondrion-associated adherens complex
# GO:0099080     1                     supramolecular complex
#
#                      namespace
# GO:0005576  cellular_component
# GO:0005623  cellular_component
# GO:0009295  cellular_component
# GO:0016020  cellular_component
# GO:0019012  cellular_component
# GO:0030054  cellular_component
# GO:0031974  cellular_component
# GO:0032991  cellular_component
# GO:0043226  cellular_component
# GO:0044215  cellular_component
# GO:0044217  cellular_component
# GO:0044421  cellular_component
# GO:0044422  cellular_component
# GO:0044423  cellular_component
# GO:0044425  cellular_component
# GO:0044456  cellular_component
# GO:0044464  cellular_component
# GO:0045202  cellular_component
# GO:0055044  cellular_component
# GO:0097423  cellular_component
# GO:0099080  cellular_component

# %%
df[df.depth == 2]
# Out:
#            depth                                               name  \
# GO:0000133     2                                         polarisome
# GO:0000313     2                                organellar ribosome
# GO:0000346     2                       transcription export complex
# GO:0000347     2                                        THO complex
# GO:0000408     2                                  EKC/KEOPS complex
# GO:0000417     2                                        HIR complex
# GO:0000439     2                                 core TFIIH complex
# GO:0000444     2                            MIS12/MIND type complex
# GO:0000776     2                                        kinetochore
# GO:0000797     2                         condensin core heterodimer
# GO:0000808     2                         origin recognition complex
# GO:0000817     2                                       COMA complex
# GO:0000930     2                              gamma-tubulin complex
# GO:0000939     2             condensed chromosome inner kinetochore
# GO:0000940     2             condensed chromosome outer kinetochore
# GO:0000974     2                                      Prp19 complex
# GO:0001114     2                            protein-DNA-RNA complex
# GO:0001534     2                                       radial spoke
# GO:0001535     2                                  radial spoke head
# GO:0001536     2                                 radial spoke stalk
# GO:0002096     2                                          polkadots
# GO:0002102     2                                           podosome
# GO:0002111     2                               BRCA2-BRAF35 complex
# GO:0002133     2                                 polycystin complex
# GO:0002142     2                     stereocilia ankle link complex
# GO:0002144     2   cytosolic tRNA wobble base thiouridylase complex
# GO:0002167     2                               VRK3/VHR/ERK complex
# GO:0002193     2                     MAML1-RBP-Jkappa- ICN1 complex
# GO:0002199     2                    zona pellucida receptor complex
# GO:0002929     2                                       MECO complex
# ...          ...                                                ...
# GO:1990615     2         Kelch-containing formin regulatory complex
# GO:1990622     2                                  CHOP-ATF3 complex
# GO:1990630     2                            IRE1-RACK1-PP2A complex
# GO:1990660     2                               calprotectin complex
# GO:1990661     2                                     S100A8 complex
# GO:1990665     2                                  AnxA2-p11 complex
# GO:1990666     2                                 PCSK9-LDLR complex
# GO:1990667     2                                PCSK9-AnxA2 complex
# GO:1990682     2                                 CSF1-CSF1R complex
# GO:1990684     2                          protein-lipid-RNA complex
# GO:1990696     2                                       USH2 complex
# GO:1990706     2                                       MAD1 complex
# GO:1990713     2                                   survivin complex
# GO:1990722     2                           DAPK1-calmodulin complex
# GO:1990727     2                   tubulin folding cofactor complex
# GO:1990728     2  mitotic spindle assembly checkpoint MAD1-MAD2 ...
# GO:1990730     2                                 VCP-NSFL1C complex
# GO:1990733     2                           titin-telethonin complex
# GO:1990745     2                                       EARP complex
# GO:1990780     2  cytoplasmic side of dendritic spine plasma mem...
# GO:1990788     2                                   GLI-SUFU complex
# GO:1990794     2                           basolateral part of cell
# GO:1990811     2                                        MWP complex
# GO:1990861     2                 Ubp3-Bre5 deubiquitination complex
# GO:1990871     2                       Vma12-Vma22 assembly complex
# GO:1990904     2                          ribonucleoprotein complex
# GO:1990909     2                                    Wnt signalosome
# GO:1990923     2                                        PET complex
# GO:1990957     2                                       NPHP complex
# GO:1990964     2              actin cytoskeleton-regulatory complex
#
#                      namespace
# GO:0000133  cellular_component
# GO:0000313  cellular_component
# GO:0000346  cellular_component
# GO:0000347  cellular_component
# GO:0000408  cellular_component
# GO:0000417  cellular_component
# GO:0000439  cellular_component
# GO:0000444  cellular_component
# GO:0000776  cellular_component
# GO:0000797  cellular_component
# GO:0000808  cellular_component
# GO:0000817  cellular_component
# GO:0000930  cellular_component
# GO:0000939  cellular_component
# GO:0000940  cellular_component
# GO:0000974  cellular_component
# GO:0001114  cellular_component
# GO:0001534  cellular_component
# GO:0001535  cellular_component
# GO:0001536  cellular_component
# GO:0002096  cellular_component
# GO:0002102  cellular_component
# GO:0002111  cellular_component
# GO:0002133  cellular_component
# GO:0002142  cellular_component
# GO:0002144  cellular_component
# GO:0002167  cellular_component
# GO:0002193  cellular_component
# GO:0002199  cellular_component
# GO:0002929  cellular_component
# ...                        ...
# GO:1990615  cellular_component
# GO:1990622  cellular_component
# GO:1990630  cellular_component
# GO:1990660  cellular_component
# GO:1990661  cellular_component
# GO:1990665  cellular_component
# GO:1990666  cellular_component
# GO:1990667  cellular_component
# GO:1990682  cellular_component
# GO:1990684  cellular_component
# GO:1990696  cellular_component
# GO:1990706  cellular_component
# GO:1990713  cellular_component
# GO:1990722  cellular_component
# GO:1990727  cellular_component
# GO:1990728  cellular_component
# GO:1990730  cellular_component
# GO:1990733  cellular_component
# GO:1990745  cellular_component
# GO:1990780  cellular_component
# GO:1990788  cellular_component
# GO:1990794  cellular_component
# GO:1990811  cellular_component
# GO:1990861  cellular_component
# GO:1990871  cellular_component
# GO:1990904  cellular_component
# GO:1990909  cellular_component
# GO:1990923  cellular_component
# GO:1990957  cellular_component
# GO:1990964  cellular_component
#
# [747 rows x 3 columns]

# %% [markdown]
# #### Depth 1 seems good.

# %% [markdown]
# ## III. Build a mapping from genes to terms via subterms

# %% [markdown]
# #### We need to find a list of terms, and for each term, all subterms. Then we can map all genes to the list of terms

# %%
level1_terms = df[df.depth == 1].index.tolist()

# %%
terms_and_subterms = {term: np.unique(flatten(list(nx.dfs_successors(g, term).values()))).tolist() for term in level1_terms}

# %%
terms = [item for l in [subterms+[term] for term, subterms in list(terms_and_subterms.items())] for item in l]
len(terms), len(np.unique(terms)), len(df)
# Out:
# (15810, 4190, 4191)

# %%
terms_and_genes = {term: genes[genes.GO_ID.isin(subterms+[term])][['GeneSymbol', 'Evidence']].values.tolist() for term, subterms in terms_and_subterms.items()}

# %%
genes_and_terms = flatten([[(gene, term, evidence) for [gene, evidence] in genes] for term, genes in terms_and_genes.items()])

# %%
evidence = pd.DataFrame(genes_and_terms, columns=['gene','GO_ID','Evidence']).groupby(['gene', 'GO_ID'])['Evidence'].apply(list).to_frame()
evidence.head()
# Out:
#                                             Evidence
# gene GO_ID
# A1BG GO:0005576  [HDA, IDA, TAS, HDA, HDA, HDA, HDA]
#      GO:0005623                      [TAS, TAS, TAS]
#      GO:0031974                      [TAS, TAS, TAS]
#      GO:0043226                 [TAS, TAS, HDA, TAS]
#      GO:0044421                 [HDA, HDA, HDA, HDA]

# %% [markdown]
# #### We need to score the evidence for each term for each gene, in cases when a gene maps to two terms

# %%
score = {**{type: 3 for type in solid_codes}, **{type: 2 for type in sketchy_codes}, **{type: 1 for type in bad_codes}}
def evidence_list_to_score_list(evidence_list): return [[score[evidence] for evidence in evidence_list]]

# %%
evidence_scores = evidence.apply(lambda row: evidence_list_to_score_list(row['Evidence']), axis=1)
evidence_scores.head()
# Out:
#                               Evidence
# gene GO_ID
# A1BG GO:0005576  [2, 3, 3, 2, 2, 2, 2]
#      GO:0005623              [3, 3, 3]
#      GO:0031974              [3, 3, 3]
#      GO:0043226           [3, 3, 2, 3]
#      GO:0044421           [2, 2, 2, 2]

# %%
evidence_scores = evidence_scores.apply(lambda row: sum(row['Evidence']), axis=1).to_frame().rename(columns={0:'Evidence'})
evidence_scores.head()
# Out:
#                  Evidence
# gene GO_ID
# A1BG GO:0005576        16
#      GO:0005623         9
#      GO:0031974         9
#      GO:0043226        11
#      GO:0044421         8

# %%
best_evidence = evidence_scores[evidence_scores['Evidence'] == evidence_scores.groupby(['gene'])['Evidence'].transform(max)]
best_evidence.head()
# Out:
#                   Evidence
# gene  GO_ID
# A1BG  GO:0005576        16
# A1CF  GO:0005623        13
#       GO:0044464        13
# A2M   GO:0005576        10
# A2ML1 GO:0005576         5

# %% [markdown]
# #### Although we don't see them here, we need to deal with ties

# %%
len(best_evidence), len(best_evidence.reset_index().drop_duplicates('gene'))
# Out:
# (44991, 19338)

# %%
best_evidence = best_evidence.reset_index().drop_duplicates('gene').set_index(['gene', 'GO_ID'])
best_evidence.head()
# Out:
#                     Evidence
# gene    GO_ID
# A1BG    GO:0005576        16
# A1CF    GO:0005623        13
# A2M     GO:0005576        10
# A2ML1   GO:0005576         5
# A3GALT2 GO:0043226         3

# %%
gene_to_compartment_term = best_evidence.reset_index()[['gene', 'GO_ID']].set_index('gene')
gene_to_compartment_term.head()
# Out:
#               GO_ID
# gene
# A1BG     GO:0005576
# A1CF     GO:0005623
# A2M      GO:0005576
# A2ML1    GO:0005576
# A3GALT2  GO:0043226

# %%
compartments = df[df.depth == 1]['name'].to_frame()
compartments
# Out:
#                                                  name
# GO:0005576                       extracellular region
# GO:0005623                                       cell
# GO:0009295                                   nucleoid
# GO:0016020                                   membrane
# GO:0019012                                     virion
# GO:0030054                              cell junction
# GO:0031974                    membrane-enclosed lumen
# GO:0032991                 protein-containing complex
# GO:0043226                                  organelle
# GO:0044215                             other organism
# GO:0044217                        other organism part
# GO:0044421                  extracellular region part
# GO:0044422                             organelle part
# GO:0044423                                virion part
# GO:0044425                              membrane part
# GO:0044456                               synapse part
# GO:0044464                                  cell part
# GO:0045202                                    synapse
# GO:0055044                                   symplast
# GO:0097423  mitochondrion-associated adherens complex
# GO:0099080                     supramolecular complex

# %%
cellular_compartments = gene_to_compartment_term.merge(compartments, how='left', left_on='GO_ID', right_index=True)[['GO_ID','name']]
cellular_compartments.head()
# Out:
#               GO_ID                  name
# gene
# A1BG     GO:0005576  extracellular region
# A1CF     GO:0005623                  cell
# A2M      GO:0005576  extracellular region
# A2ML1    GO:0005576  extracellular region
# A3GALT2  GO:0043226             organelle

# %% [markdown]
# ## IV. Add "Specific Compartments" information to each gene

# %%
level2_terms = df[df.depth == 2].index.tolist()

# %%
terms_and_subterms = {term: np.unique(flatten(list(nx.dfs_successors(g, term).values()))).tolist() for term in level2_terms}

# %%
terms = [item for l in [subterms+[term] for term, subterms in list(terms_and_subterms.items())] for item in l]
len(terms), len(np.unique(terms)), len(df)
# Out:
# (19818, 4169, 4191)

# %%
terms_and_genes = {term: genes[genes.GO_ID.isin(subterms+[term])][['GeneSymbol', 'Evidence']].values.tolist() for term, subterms in terms_and_subterms.items()}

# %%
genes_and_terms = flatten([[(gene, term, evidence) for [gene, evidence] in genes] for term, genes in terms_and_genes.items()])

# %%
evidence = pd.DataFrame(genes_and_terms, columns=['gene','GO_ID','Evidence']).groupby(['gene', 'GO_ID'])['Evidence'].apply(list).to_frame()
evidence.head()
# Out:
#                              Evidence
# gene GO_ID
# A1BG GO:0005615       [HDA, HDA, HDA]
#      GO:0005622       [TAS, TAS, TAS]
#      GO:0012505       [TAS, TAS, TAS]
#      GO:0031012                 [HDA]
#      GO:0043227  [TAS, TAS, HDA, TAS]

# %% [markdown]
# #### We've made a committment for each gene to belong to a single level1 term, so let's remove all the level2 terms which aren't subterms of the previously selected level1 term for each gene

# %%
predecessors = {term: list(g.predecessors(term)) for term in level2_terms}

# %%
predecessors = {term: [parent for parent in parents if parent in level1_terms] for term, parents in predecessors.items()}

# %%
predecessors = {term: parents[0] for term, parents in predecessors.items()}

# %%
predecessors = pd.Series(predecessors).rename_axis('level2_term').rename('level1_term').to_frame()
predecessors.head()
# Out:
#             level1_term
# level2_term
# GO:0000133   GO:0032991
# GO:0000313   GO:0044422
# GO:0000346   GO:0032991
# GO:0000347   GO:0032991
# GO:0000408   GO:0032991

# %%
evidence = evidence.reset_index().merge(predecessors, how='left', left_on='GO_ID', right_index=True).set_index(['gene', 'level1_term', 'GO_ID'])
evidence.head()
# Out:
#                                          Evidence
# gene level1_term GO_ID
# A1BG GO:0044421  GO:0005615       [HDA, HDA, HDA]
#      GO:0044464  GO:0005622       [TAS, TAS, TAS]
#                  GO:0012505       [TAS, TAS, TAS]
#      GO:0044421  GO:0031012                 [HDA]
#      GO:0043226  GO:0043227  [TAS, TAS, HDA, TAS]

# %%
evidence = evidence.reset_index().merge(cellular_compartments['GO_ID'].rename('chosen_level1').to_frame(), how='left', left_on='gene', right_index=True)
evidence = evidence[evidence.level1_term == evidence.chosen_level1]
evidence = evidence.set_index(['gene','GO_ID'])['Evidence'].to_frame()
evidence.head()
# Out:
#                            Evidence
# gene    GO_ID
# A3GALT2 GO:0043227  [IBA, IBA, IEA]
#         GO:0043229       [IBA, IEA]
# A4GALT  GO:0031090            [NAS]
# A4GNT   GO:0031090            [TAS]
# AADAC   GO:0005789  [IBA, IDA, TAS]

# %%
evidence_scores = evidence.apply(lambda row: evidence_list_to_score_list(row['Evidence']), axis=1)
evidence_scores.head()
# Out:
#                      Evidence
# gene    GO_ID
# A3GALT2 GO:0043227  [1, 1, 1]
#         GO:0043229     [1, 1]
# A4GALT  GO:0031090        [3]
# A4GNT   GO:0031090        [3]
# AADAC   GO:0005789  [1, 3, 3]

# %%
evidence_scores = evidence_scores.apply(lambda row: sum(row['Evidence']), axis=1).to_frame().rename(columns={0:'Evidence'})
evidence_scores.head()
# Out:
#                     Evidence
# gene    GO_ID
# A3GALT2 GO:0043227         3
#         GO:0043229         2
# A4GALT  GO:0031090         3
# A4GNT   GO:0031090         3
# AADAC   GO:0005789         7

# %%
best_evidence = evidence_scores[evidence_scores['Evidence'] == evidence_scores.groupby(['gene'])['Evidence'].transform(max)]
best_evidence.head()
# Out:
#                     Evidence
# gene    GO_ID
# A3GALT2 GO:0043227         3
# A4GALT  GO:0031090         3
# A4GNT   GO:0031090         3
# AADAC   GO:0005789         7
# ABCA4   GO:0031090         3

# %%
len(best_evidence), len(best_evidence.reset_index().drop_duplicates('gene'))
# Out:
# (1683, 1422)

# %%
best_evidence = best_evidence.reset_index().drop_duplicates('gene').set_index(['gene', 'GO_ID'])
best_evidence.head()
# Out:
#                     Evidence
# gene    GO_ID
# A3GALT2 GO:0043227         3
# A4GALT  GO:0031090         3
# A4GNT   GO:0031090         3
# AADAC   GO:0005789         7
# ABCA4   GO:0031090         3

# %%
gene_to_compartment_term = best_evidence.reset_index()[['gene', 'GO_ID']].set_index('gene')
gene_to_compartment_term.head()
# Out:
#               GO_ID
# gene
# A3GALT2  GO:0043227
# A4GALT   GO:0031090
# A4GNT    GO:0031090
# AADAC    GO:0005789
# ABCA4    GO:0031090

# %%
compartments = df[df.depth == 2]['name'].to_frame()
compartments
# Out:
#                                                          name
# GO:0000133                                         polarisome
# GO:0000313                                organellar ribosome
# GO:0000346                       transcription export complex
# GO:0000347                                        THO complex
# GO:0000408                                  EKC/KEOPS complex
# GO:0000417                                        HIR complex
# GO:0000439                                 core TFIIH complex
# GO:0000444                            MIS12/MIND type complex
# GO:0000776                                        kinetochore
# GO:0000797                         condensin core heterodimer
# GO:0000808                         origin recognition complex
# GO:0000817                                       COMA complex
# GO:0000930                              gamma-tubulin complex
# GO:0000939             condensed chromosome inner kinetochore
# GO:0000940             condensed chromosome outer kinetochore
# GO:0000974                                      Prp19 complex
# GO:0001114                            protein-DNA-RNA complex
# GO:0001534                                       radial spoke
# GO:0001535                                  radial spoke head
# GO:0001536                                 radial spoke stalk
# GO:0002096                                          polkadots
# GO:0002102                                           podosome
# GO:0002111                               BRCA2-BRAF35 complex
# GO:0002133                                 polycystin complex
# GO:0002142                     stereocilia ankle link complex
# GO:0002144   cytosolic tRNA wobble base thiouridylase complex
# GO:0002167                               VRK3/VHR/ERK complex
# GO:0002193                     MAML1-RBP-Jkappa- ICN1 complex
# GO:0002199                    zona pellucida receptor complex
# GO:0002929                                       MECO complex
# ...                                                       ...
# GO:1990615         Kelch-containing formin regulatory complex
# GO:1990622                                  CHOP-ATF3 complex
# GO:1990630                            IRE1-RACK1-PP2A complex
# GO:1990660                               calprotectin complex
# GO:1990661                                     S100A8 complex
# GO:1990665                                  AnxA2-p11 complex
# GO:1990666                                 PCSK9-LDLR complex
# GO:1990667                                PCSK9-AnxA2 complex
# GO:1990682                                 CSF1-CSF1R complex
# GO:1990684                          protein-lipid-RNA complex
# GO:1990696                                       USH2 complex
# GO:1990706                                       MAD1 complex
# GO:1990713                                   survivin complex
# GO:1990722                           DAPK1-calmodulin complex
# GO:1990727                   tubulin folding cofactor complex
# GO:1990728  mitotic spindle assembly checkpoint MAD1-MAD2 ...
# GO:1990730                                 VCP-NSFL1C complex
# GO:1990733                           titin-telethonin complex
# GO:1990745                                       EARP complex
# GO:1990780  cytoplasmic side of dendritic spine plasma mem...
# GO:1990788                                   GLI-SUFU complex
# GO:1990794                           basolateral part of cell
# GO:1990811                                        MWP complex
# GO:1990861                 Ubp3-Bre5 deubiquitination complex
# GO:1990871                       Vma12-Vma22 assembly complex
# GO:1990904                          ribonucleoprotein complex
# GO:1990909                                    Wnt signalosome
# GO:1990923                                        PET complex
# GO:1990957                                       NPHP complex
# GO:1990964              actin cytoskeleton-regulatory complex
#
# [747 rows x 1 columns]

# %%
specific_cellular_compartments = gene_to_compartment_term.merge(compartments, how='left', left_on='GO_ID', right_index=True)[['GO_ID','name']]
specific_cellular_compartments.head()
# Out:
#               GO_ID                            name
# gene
# A3GALT2  GO:0043227      membrane-bounded organelle
# A4GALT   GO:0031090              organelle membrane
# A4GNT    GO:0031090              organelle membrane
# AADAC    GO:0005789  endoplasmic reticulum membrane
# ABCA4    GO:0031090              organelle membrane

# %%
cellular_compartments = cellular_compartments.rename(columns={'GO_ID':'general_compartment_GO_ID', 'name':'general_compartment'})
cellular_compartments.head()
# Out:
#         general_compartment_GO_ID   general_compartment
# gene
# A1BG                   GO:0005576  extracellular region
# A1CF                   GO:0005623                  cell
# A2M                    GO:0005576  extracellular region
# A2ML1                  GO:0005576  extracellular region
# A3GALT2                GO:0043226             organelle

# %%
cellular_compartments = cellular_compartments.merge(specific_cellular_compartments, how='left', left_index=True, right_index=True).rename(columns={'GO_ID':'specific_process_GO_ID', 'name':'specific_process'})
cellular_compartments.head()
# Out:
#         general_compartment_GO_ID   general_compartment  \
# gene
# A1BG                   GO:0005576  extracellular region
# A1CF                   GO:0005623                  cell
# A2M                    GO:0005576  extracellular region
# A2ML1                  GO:0005576  extracellular region
# A3GALT2                GO:0043226             organelle
#
#         specific_process_GO_ID            specific_process
# gene
# A1BG                       NaN                         NaN
# A1CF                       NaN                         NaN
# A2M                        NaN                         NaN
# A2ML1                      NaN                         NaN
# A3GALT2             GO:0043227  membrane-bounded organelle

# %% [markdown]
# ## This subcellular localization annotation is not as refined as the one generated by Bryce from the COMPARTMENTS database, so we will neglect to save it.

# %%
# cellular_compartments.to_pickle('cellular_compartments_gene_annotation.pickle')

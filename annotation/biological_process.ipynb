# %% [markdown]
# # Creating a Biological Process Reference for OmicsIntegrator2

# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import defaultdict

def flatten(list_of_lists): return [item for sublist in list_of_lists for item in sublist]

import mygene

# %%
genes = pd.read_csv('../../GONN/GO/biological_process.csv')
genes.head()
# Out:
#   GeneSymbol       GO_ID                                            GO_term  \
# 0       A1BG  GO:0002576                             platelet degranulation
# 1       A1BG  GO:0008150                                 biological_process
# 2       A1BG  GO:0043312                           neutrophil degranulation
# 3        A2M  GO:0001869  negative regulation of complement activation, ...
# 4        A2M  GO:0002576                             platelet degranulation
#
#   Evidence
# 0      TAS
# 1       ND
# 2      TAS
# 3      IDA
# 4      TAS

# %% [markdown]
# ## I. Evidence Codes
#
# Copied from http://geneontology.org/page/guide-go-evidence-codes
#
# ### Experimental Evidence codes
# Use of an experimental evidence code in a GO annotation indicates that the cited paper displayed results from a physical characterization of a gene or gene product that has supported the association of a GO term. The Experimental Evidence codes are:
#
# - Inferred from Experiment (EXP)
# - Inferred from Direct Assay (IDA)
# - Inferred from Physical Interaction (IPI)
# - Inferred from Mutant Phenotype (IMP)
# - Inferred from Genetic Interaction (IGI)
# - Inferred from Expression Pattern (IEP)
#
# ### High Throughput (HTP) evidence codes
# High throughput (HTP) evidence codes may be used to make annotations based upon high throughput methodologies. Use of HTP evidence codes should be carefully considered and follow the GOC's guidelines for their use. The High Throughput Evidence Codes are:
#
# - Inferred from High Throughput Experiment (HTP)
# - Inferred from High Throughput Direct Assay (HDA)
# - Inferred from Hight Throughput Mutant Phenotype (HMP)
# - Inferred from High Throughput Genetic Interaction (HGI)
# - Inferred from High Throughput Expression Pattern (HEP)
#
# ### Computational Analysis evidence codes
# Use of the computational analysis evidence codes indicates that the annotation is based on an in silico analysis of the gene sequence and/or other data as described in the cited reference. The evidence codes in this category also indicate a varying degree of curatorial input. The Computational Analysis evidence codes are:
#
# - Inferred from Sequence or structural Similarity (ISS)
# - Inferred from Sequence Orthology (ISO)
# - Inferred from Sequence Alignment (ISA)
# - Inferred from Sequence Model (ISM)
# - Inferred from Genomic Context (IGC)
# - Inferred from Biological aspect of Ancestor (IBA)
# - Inferred from Biological aspect of Descendant (IBD)
# - Inferred from Key Residues (IKR)
# - Inferred from Rapid Divergence (IRD)
# - Inferred from Reviewed Computational Analysis (RCA)
#
# ### Author statement evidence codes
# Author statement codes indicate that the annotation was made on the basis of a statement made by the author(s) in the reference cited. The Author Statement evidence codes are:
#
# - Traceable Author Statement (TAS)
# - Non-traceable Author Statement (NAS)
#
# ### Curator statement evidence codes
# Use of the curatorial statement evidence codes indicates an annotation made on the basis of a curatorial judgement that does not fit into one of the other evidence code classifications. The Curatorial Statement codes:
#
# - Inferred by Curator (IC)
# - No biological Data available (ND)
#
# ### Electronic Annotation evidence code
# All of the above evidence codes are assigned by curators. However, GO also uses one evidence code that is assigned by automated methods, without curatorial judgement. The Automatically-Assigned evidence code is
#
# - Inferred from Electronic Annotation (IEA)

# %%
solid_codes = ['EXP','IDA','IPI','IMP','IGI','IEP','TAS','NAS']
sketchy_codes = ['HTP','HDA','HMP','HGI','HEP','IC']
bad_codes = ['ISS','ISO','ISA','ISM','IGC','IBA','IBD','IKR','IRD','RCA','IEA','ND']
             
{'solid': len(genes[genes['Evidence'].isin(solid_codes)]), 'sketchy': len(genes[genes['Evidence'].isin(sketchy_codes)]), 'bad': len(genes[genes['Evidence'].isin(bad_codes)])}
# Out:
# {'bad': 82024, 'sketchy': 1103, 'solid': 66059}

# %% [markdown]
# ## II. Find good ontology depth

# %%
g = nx.read_gpickle('../../GONN/GO/GO_biological_process.pickle')
g

# %%
df = pd.DataFrame.from_dict(dict(g.nodes(data=True))).transpose()
df.head()
# Out:
#            depth                              name           namespace
# GO:0000001     5         mitochondrion inheritance  biological_process
# GO:0000002     5  mitochondrial genome maintenance  biological_process
# GO:0000003     1                      reproduction  biological_process
# GO:0000011     5               vacuole inheritance  biological_process
# GO:0000012     6        single strand break repair  biological_process

# %%
df[df.depth == 0]
# Out:
#            depth                name           namespace
# GO:0008150     0  biological_process  biological_process

# %%
df[df.depth == 1]
# Out:
#            depth                                           name  \
# GO:0000003     1                                   reproduction
# GO:0001906     1                                   cell killing
# GO:0002376     1                          immune system process
# GO:0006791     1                             sulfur utilization
# GO:0006794     1                         phosphorus utilization
# GO:0007610     1                                       behavior
# GO:0008152     1                              metabolic process
# GO:0008283     1                             cell proliferation
# GO:0009758     1                       carbohydrate utilization
# GO:0009987     1                               cellular process
# GO:0015976     1                             carbon utilization
# GO:0019740     1                           nitrogen utilization
# GO:0022414     1                           reproductive process
# GO:0022610     1                            biological adhesion
# GO:0023052     1                                      signaling
# GO:0032501     1               multicellular organismal process
# GO:0032502     1                          developmental process
# GO:0040007     1                                         growth
# GO:0040011     1                                     locomotion
# GO:0043473     1                                   pigmentation
# GO:0044848     1                               biological phase
# GO:0048511     1                               rhythmic process
# GO:0050896     1                           response to stimulus
# GO:0051179     1                                   localization
# GO:0051704     1                         multi-organism process
# GO:0065007     1                          biological regulation
# GO:0071840     1  cellular component organization or biogenesis
# GO:0098743     1                               cell aggregation
# GO:0098754     1                                 detoxification
#
#                      namespace
# GO:0000003  biological_process
# GO:0001906  biological_process
# GO:0002376  biological_process
# GO:0006791  biological_process
# GO:0006794  biological_process
# GO:0007610  biological_process
# GO:0008152  biological_process
# GO:0008283  biological_process
# GO:0009758  biological_process
# GO:0009987  biological_process
# GO:0015976  biological_process
# GO:0019740  biological_process
# GO:0022414  biological_process
# GO:0022610  biological_process
# GO:0023052  biological_process
# GO:0032501  biological_process
# GO:0032502  biological_process
# GO:0040007  biological_process
# GO:0040011  biological_process
# GO:0043473  biological_process
# GO:0044848  biological_process
# GO:0048511  biological_process
# GO:0050896  biological_process
# GO:0051179  biological_process
# GO:0051704  biological_process
# GO:0065007  biological_process
# GO:0071840  biological_process
# GO:0098743  biological_process
# GO:0098754  biological_process

# %%
df[df.depth == 2]
# Out:
#            depth                                               name  \
# GO:0000075     2                              cell cycle checkpoint
# GO:0000728     2  gene conversion at mating-type locus, DNA doub...
# GO:0000734     2  gene conversion at mating-type locus, DNA repa...
# GO:0000742     2  karyogamy involved in conjugation with cellula...
# GO:0000743     2  nuclear migration involved in conjugation with...
# GO:0000920     2                  cell separation after cytokinesis
# GO:0001502     2                             cartilage condensation
# GO:0001503     2                                       ossification
# GO:0001545     2                    primary ovarian follicle growth
# GO:0001546     2                  preantral ovarian follicle growth
# GO:0001550     2                          ovarian cumulus expansion
# GO:0001763     2             morphogenesis of a branching structure
# GO:0001775     2                                    cell activation
# GO:0001776     2                              leukocyte homeostasis
# GO:0001816     2                                cytokine production
# GO:0001833     2                 inner cell mass cell proliferation
# GO:0001834     2                 trophectodermal cell proliferation
# GO:0001909     2                    leukocyte mediated cytotoxicity
# GO:0002021     2                         response to dietary excess
# GO:0002077     2                          acrosome matrix dispersal
# GO:0002174     2                    mammary stem cell proliferation
# GO:0002200     2        somatic diversification of immune receptors
# GO:0002209     2                        behavioral defense response
# GO:0002210     2                    behavioral response to wounding
# GO:0002252     2                            immune effector process
# GO:0002253     2                      activation of immune response
# GO:0002262     2                           myeloid cell homeostasis
# GO:0002339     2                                   B cell selection
# GO:0002404     2  antigen sampling in mucosal-associated lymphoi...
# GO:0002440     2  production of molecular mediator of immune res...
# ...          ...                                                ...
# GO:0090618     2                                DNA clamp unloading
# GO:0090644     2                             age-related resistance
# GO:0090664     2                response to high population density
# GO:0090675     2                          intermicrovillar adhesion
# GO:0090713     2                       immunological memory process
# GO:0097167     2                circadian regulation of translation
# GO:0097194     2                       execution phase of apoptosis
# GO:0097207     2                               bud dormancy process
# GO:0097242     2                             amyloid-beta clearance
# GO:0097278     2                  complement-dependent cytotoxicity
# GO:0097360     2           chorionic trophoblast cell proliferation
# GO:0097528     2                     execution phase of necroptosis
# GO:0097737     2    acquisition of mycelium reproductive competence
# GO:0098630     2               aggregation of unicellular organisms
# GO:0098727     2                         maintenance of cell number
# GO:0098740     2                       multi organism cell adhesion
# GO:0140029     2                                   exocytic process
# GO:1901275     2                         tartrate metabolic process
# GO:1901902     2                       tyrocidine metabolic process
# GO:1902064     2  regulation of transcription from RNA polymeras...
# GO:1902397     2  detection of stimulus involved in meiotic spin...
# GO:1902421     2                         hydrogen metabolic process
# GO:1902441     2  protein localization to meiotic spindle pole body
# GO:1902579     2                        multi-organism localization
# GO:1903046     2                         meiotic cell cycle process
# GO:1990110     2                                   callus formation
# GO:1990654     2                 sebum secreting cell proliferation
# GO:1990748     2                            cellular detoxification
# GO:1990845     2                             adaptive thermogenesis
# GO:2000793     2  cell proliferation involved in heart valve dev...
#
#                      namespace
# GO:0000075  biological_process
# GO:0000728  biological_process
# GO:0000734  biological_process
# GO:0000742  biological_process
# GO:0000743  biological_process
# GO:0000920  biological_process
# GO:0001502  biological_process
# GO:0001503  biological_process
# GO:0001545  biological_process
# GO:0001546  biological_process
# GO:0001550  biological_process
# GO:0001763  biological_process
# GO:0001775  biological_process
# GO:0001776  biological_process
# GO:0001816  biological_process
# GO:0001833  biological_process
# GO:0001834  biological_process
# GO:0001909  biological_process
# GO:0002021  biological_process
# GO:0002077  biological_process
# GO:0002174  biological_process
# GO:0002200  biological_process
# GO:0002209  biological_process
# GO:0002210  biological_process
# GO:0002252  biological_process
# GO:0002253  biological_process
# GO:0002262  biological_process
# GO:0002339  biological_process
# GO:0002404  biological_process
# GO:0002440  biological_process
# ...                        ...
# GO:0090618  biological_process
# GO:0090644  biological_process
# GO:0090664  biological_process
# GO:0090675  biological_process
# GO:0090713  biological_process
# GO:0097167  biological_process
# GO:0097194  biological_process
# GO:0097207  biological_process
# GO:0097242  biological_process
# GO:0097278  biological_process
# GO:0097360  biological_process
# GO:0097528  biological_process
# GO:0097737  biological_process
# GO:0098630  biological_process
# GO:0098727  biological_process
# GO:0098740  biological_process
# GO:0140029  biological_process
# GO:1901275  biological_process
# GO:1901902  biological_process
# GO:1902064  biological_process
# GO:1902397  biological_process
# GO:1902421  biological_process
# GO:1902441  biological_process
# GO:1902579  biological_process
# GO:1903046  biological_process
# GO:1990110  biological_process
# GO:1990654  biological_process
# GO:1990748  biological_process
# GO:1990845  biological_process
# GO:2000793  biological_process
#
# [423 rows x 3 columns]

# %% [markdown]
# #### Depth 1 seems good.

# %% [markdown]
# ## III. Build a mapping from genes to terms via subterms

# %% [markdown]
# #### We need to find a list of terms, and for each term, all subterms. Then we can map all genes to the list of terms

# %%
level1_terms = df[df.depth == 1].index.tolist()

# %%
terms_and_subterms = {term: np.unique(flatten(list(nx.dfs_successors(g, term).values()))).tolist() for term in level1_terms}

# %%
terms = [item for l in [subterms+[term] for term, subterms in list(terms_and_subterms.items())] for item in l]
len(terms), len(np.unique(terms)), len(df)
# Out:
# (57113, 29617, 29618)

# %%
terms_and_genes = {term: genes[genes.GO_ID.isin(subterms+[term])][['GeneSymbol', 'Evidence']].values.tolist() for term, subterms in terms_and_subterms.items()}

# %%
genes_and_terms = flatten([[(gene, term, evidence) for [gene, evidence] in genes] for term, genes in terms_and_genes.items()])

# %%
evidence = pd.DataFrame(genes_and_terms, columns=['gene','GO_ID','Evidence']).groupby(['gene', 'GO_ID'])['Evidence'].apply(list).to_frame()
evidence.head()
# Out:
#                         Evidence
# gene GO_ID
# A1BG GO:0002376            [TAS]
#      GO:0009987       [TAS, TAS]
#      GO:0050896            [TAS]
#      GO:0051179       [TAS, TAS]
# A1CF GO:0008152  [IEA, TAS, IEA]

# %% [markdown]
# #### We need to score the evidence for each term for each gene, in cases when a gene maps to two terms

# %%
score = {**{type: 3 for type in solid_codes}, **{type: 2 for type in sketchy_codes}, **{type: 1 for type in bad_codes}}
def evidence_list_to_score_list(evidence_list): return [[score[evidence] for evidence in evidence_list]]

# %%
evidence_scores = evidence.apply(lambda row: evidence_list_to_score_list(row['Evidence']), axis=1)
evidence_scores.head()
# Out:
#                   Evidence
# gene GO_ID
# A1BG GO:0002376        [3]
#      GO:0009987     [3, 3]
#      GO:0050896        [3]
#      GO:0051179     [3, 3]
# A1CF GO:0008152  [1, 3, 1]

# %%
evidence_scores = evidence_scores.apply(lambda row: sum(row['Evidence']), axis=1).to_frame().rename(columns={0:'Evidence'})
evidence_scores.head()
# Out:
#                  Evidence
# gene GO_ID
# A1BG GO:0002376         3
#      GO:0009987         6
#      GO:0050896         3
#      GO:0051179         6
# A1CF GO:0008152         5

# %%
best_evidence = evidence_scores[evidence_scores['Evidence'] == evidence_scores.groupby(['gene'])['Evidence'].transform(max)]
best_evidence.head()
# Out:
#                  Evidence
# gene GO_ID
# A1BG GO:0009987         6
#      GO:0051179         6
# A1CF GO:0008152         5
#      GO:0009987         5
# A2M  GO:0065007        11

# %% [markdown]
# #### Although we don't see them here, we need to deal with ties

# %%
len(best_evidence), len(best_evidence.reset_index().drop_duplicates('gene'))
# Out:
# (27418, 18306)

# %%
best_evidence = best_evidence.reset_index().drop_duplicates('gene').set_index(['gene', 'GO_ID'])
best_evidence.head()
# Out:
#                     Evidence
# gene    GO_ID
# A1BG    GO:0009987         6
# A1CF    GO:0008152         5
# A2M     GO:0065007        11
# A2ML1   GO:0065007         4
# A3GALT2 GO:0008152         3

# %%
gene_to_process_term = best_evidence.reset_index()[['gene', 'GO_ID']].set_index('gene')
gene_to_process_term.head()
# Out:
#               GO_ID
# gene
# A1BG     GO:0009987
# A1CF     GO:0008152
# A2M      GO:0065007
# A2ML1    GO:0065007
# A3GALT2  GO:0008152

# %%
processes = df[df.depth == 1]['name'].to_frame()
processes
# Out:
#                                                      name
# GO:0000003                                   reproduction
# GO:0001906                                   cell killing
# GO:0002376                          immune system process
# GO:0006791                             sulfur utilization
# GO:0006794                         phosphorus utilization
# GO:0007610                                       behavior
# GO:0008152                              metabolic process
# GO:0008283                             cell proliferation
# GO:0009758                       carbohydrate utilization
# GO:0009987                               cellular process
# GO:0015976                             carbon utilization
# GO:0019740                           nitrogen utilization
# GO:0022414                           reproductive process
# GO:0022610                            biological adhesion
# GO:0023052                                      signaling
# GO:0032501               multicellular organismal process
# GO:0032502                          developmental process
# GO:0040007                                         growth
# GO:0040011                                     locomotion
# GO:0043473                                   pigmentation
# GO:0044848                               biological phase
# GO:0048511                               rhythmic process
# GO:0050896                           response to stimulus
# GO:0051179                                   localization
# GO:0051704                         multi-organism process
# GO:0065007                          biological regulation
# GO:0071840  cellular component organization or biogenesis
# GO:0098743                               cell aggregation
# GO:0098754                                 detoxification

# %%
biological_processes = gene_to_process_term.merge(processes, how='left', left_on='GO_ID', right_index=True)[['GO_ID','name']]
biological_processes.head()
# Out:
#               GO_ID                   name
# gene
# A1BG     GO:0009987       cellular process
# A1CF     GO:0008152      metabolic process
# A2M      GO:0065007  biological regulation
# A2ML1    GO:0065007  biological regulation
# A3GALT2  GO:0008152      metabolic process

# %% [markdown]
# ## IV. Add "Specific Process" information to each gene

# %%
level2_terms = df[df.depth == 2].index.tolist()

# %%
terms_and_subterms = {term: np.unique(flatten(list(nx.dfs_successors(g, term).values()))).tolist() for term in level2_terms}

# %%
terms = [item for l in [subterms+[term] for term, subterms in list(terms_and_subterms.items())] for item in l]
len(terms), len(np.unique(terms)), len(df)
# Out:
# (84432, 29589, 29618)

# %%
terms_and_genes = {term: genes[genes.GO_ID.isin(subterms+[term])][['GeneSymbol', 'Evidence']].values.tolist() for term, subterms in terms_and_subterms.items()}

# %%
genes_and_terms = flatten([[(gene, term, evidence) for [gene, evidence] in genes] for term, genes in terms_and_genes.items()])

# %%
evidence = pd.DataFrame(genes_and_terms, columns=['gene','GO_ID','Evidence']).groupby(['gene', 'GO_ID'])['Evidence'].apply(list).to_frame()
evidence.head()
# Out:
#                    Evidence
# gene GO_ID
# A1BG GO:0001775       [TAS]
#      GO:0002252       [TAS]
#      GO:0006955       [TAS]
#      GO:0032940  [TAS, TAS]
#      GO:0045321       [TAS]

# %% [markdown]
# #### We've made a committment for each gene to belong to a single level1 term, so let's remove all the level2 terms which aren't subterms of the previously selected level1 term for each gene

# %%
predecessors = {term: list(g.predecessors(term)) for term in level2_terms}

# %%
predecessors = {term: [parent for parent in parents if parent in level1_terms] for term, parents in predecessors.items()}

# %%
predecessors = {term: parents[0] for term, parents in predecessors.items()}

# %%
predecessors = pd.Series(predecessors).rename_axis('level2_term').rename('level1_term').to_frame()
predecessors.head()
# Out:
#             level1_term
# level2_term
# GO:0000075   GO:0009987
# GO:0000728   GO:0022414
# GO:0000734   GO:0022414
# GO:0000742   GO:0022414
# GO:0000743   GO:0022414

# %%
evidence = evidence.reset_index().merge(predecessors, how='left', left_on='GO_ID', right_index=True).set_index(['gene', 'level1_term', 'GO_ID'])
evidence.head()
# Out:
#                                Evidence
# gene level1_term GO_ID
# A1BG GO:0009987  GO:0001775       [TAS]
#      GO:0002376  GO:0002252       [TAS]
#      GO:0050896  GO:0006955       [TAS]
#      GO:0009987  GO:0032940  [TAS, TAS]
#      GO:0002376  GO:0045321       [TAS]

# %%
evidence = evidence.reset_index().merge(biological_processes['GO_ID'].rename('chosen_level1').to_frame(), how='left', left_on='gene', right_index=True)
evidence = evidence[evidence.level1_term == evidence.chosen_level1]
evidence = evidence.set_index(['gene','GO_ID'])['Evidence'].to_frame()
evidence.head()
# Out:
#                         Evidence
# gene GO_ID
# A1BG GO:0001775            [TAS]
#      GO:0032940       [TAS, TAS]
# A1CF GO:0006807  [IEA, TAS, IEA]
#      GO:0044237  [IEA, TAS, IEA]
#      GO:0044238  [IEA, TAS, IEA]

# %%
evidence_scores = evidence.apply(lambda row: evidence_list_to_score_list(row['Evidence']), axis=1)
evidence_scores.head()
# Out:
#                   Evidence
# gene GO_ID
# A1BG GO:0001775        [3]
#      GO:0032940     [3, 3]
# A1CF GO:0006807  [1, 3, 1]
#      GO:0044237  [1, 3, 1]
#      GO:0044238  [1, 3, 1]

# %%
evidence_scores = evidence_scores.apply(lambda row: sum(row['Evidence']), axis=1).to_frame().rename(columns={0:'Evidence'})
evidence_scores.head()
# Out:
#                  Evidence
# gene GO_ID
# A1BG GO:0001775         3
#      GO:0032940         6
# A1CF GO:0006807         5
#      GO:0044237         5
#      GO:0044238         5

# %%
best_evidence = evidence_scores[evidence_scores['Evidence'] == evidence_scores.groupby(['gene'])['Evidence'].transform(max)]
best_evidence.head()
# Out:
#                  Evidence
# gene GO_ID
# A1BG GO:0032940         6
# A1CF GO:0006807         5
#      GO:0044237         5
#      GO:0044238         5
#      GO:0071704         5

# %%
len(best_evidence), len(best_evidence.reset_index().drop_duplicates('gene'))
# Out:
# (33255, 18153)

# %%
best_evidence = best_evidence.reset_index().drop_duplicates('gene').set_index(['gene', 'GO_ID'])
best_evidence.head()
# Out:
#                     Evidence
# gene    GO_ID
# A1BG    GO:0032940         6
# A1CF    GO:0006807         5
# A2M     GO:0050789         7
# A2ML1   GO:0050789         4
# A3GALT2 GO:0044238         3

# %%
gene_to_process_term = best_evidence.reset_index()[['gene', 'GO_ID']].set_index('gene')
gene_to_process_term.head()
# Out:
#               GO_ID
# gene
# A1BG     GO:0032940
# A1CF     GO:0006807
# A2M      GO:0050789
# A2ML1    GO:0050789
# A3GALT2  GO:0044238

# %%
processes = df[df.depth == 2]['name'].to_frame()
processes
# Out:
#                                                          name
# GO:0000075                              cell cycle checkpoint
# GO:0000728  gene conversion at mating-type locus, DNA doub...
# GO:0000734  gene conversion at mating-type locus, DNA repa...
# GO:0000742  karyogamy involved in conjugation with cellula...
# GO:0000743  nuclear migration involved in conjugation with...
# GO:0000920                  cell separation after cytokinesis
# GO:0001502                             cartilage condensation
# GO:0001503                                       ossification
# GO:0001545                    primary ovarian follicle growth
# GO:0001546                  preantral ovarian follicle growth
# GO:0001550                          ovarian cumulus expansion
# GO:0001763             morphogenesis of a branching structure
# GO:0001775                                    cell activation
# GO:0001776                              leukocyte homeostasis
# GO:0001816                                cytokine production
# GO:0001833                 inner cell mass cell proliferation
# GO:0001834                 trophectodermal cell proliferation
# GO:0001909                    leukocyte mediated cytotoxicity
# GO:0002021                         response to dietary excess
# GO:0002077                          acrosome matrix dispersal
# GO:0002174                    mammary stem cell proliferation
# GO:0002200        somatic diversification of immune receptors
# GO:0002209                        behavioral defense response
# GO:0002210                    behavioral response to wounding
# GO:0002252                            immune effector process
# GO:0002253                      activation of immune response
# GO:0002262                           myeloid cell homeostasis
# GO:0002339                                   B cell selection
# GO:0002404  antigen sampling in mucosal-associated lymphoi...
# GO:0002440  production of molecular mediator of immune res...
# ...                                                       ...
# GO:0090618                                DNA clamp unloading
# GO:0090644                             age-related resistance
# GO:0090664                response to high population density
# GO:0090675                          intermicrovillar adhesion
# GO:0090713                       immunological memory process
# GO:0097167                circadian regulation of translation
# GO:0097194                       execution phase of apoptosis
# GO:0097207                               bud dormancy process
# GO:0097242                             amyloid-beta clearance
# GO:0097278                  complement-dependent cytotoxicity
# GO:0097360           chorionic trophoblast cell proliferation
# GO:0097528                     execution phase of necroptosis
# GO:0097737    acquisition of mycelium reproductive competence
# GO:0098630               aggregation of unicellular organisms
# GO:0098727                         maintenance of cell number
# GO:0098740                       multi organism cell adhesion
# GO:0140029                                   exocytic process
# GO:1901275                         tartrate metabolic process
# GO:1901902                       tyrocidine metabolic process
# GO:1902064  regulation of transcription from RNA polymeras...
# GO:1902397  detection of stimulus involved in meiotic spin...
# GO:1902421                         hydrogen metabolic process
# GO:1902441  protein localization to meiotic spindle pole body
# GO:1902579                        multi-organism localization
# GO:1903046                         meiotic cell cycle process
# GO:1990110                                   callus formation
# GO:1990654                 sebum secreting cell proliferation
# GO:1990748                            cellular detoxification
# GO:1990845                             adaptive thermogenesis
# GO:2000793  cell proliferation involved in heart valve dev...
#
# [423 rows x 1 columns]

# %%
specific_biological_processes = gene_to_process_term.merge(processes, how='left', left_on='GO_ID', right_index=True)[['GO_ID','name']]
specific_biological_processes.head()
# Out:
#               GO_ID                                 name
# gene
# A1BG     GO:0032940                    secretion by cell
# A1CF     GO:0006807  nitrogen compound metabolic process
# A2M      GO:0050789     regulation of biological process
# A2ML1    GO:0050789     regulation of biological process
# A3GALT2  GO:0044238            primary metabolic process

# %%
biological_processes = biological_processes.rename(columns={'GO_ID':'general_process_GO_ID', 'name':'general_process'})
biological_processes.head()
# Out:
#         general_process_GO_ID        general_process
# gene
# A1BG               GO:0009987       cellular process
# A1CF               GO:0008152      metabolic process
# A2M                GO:0065007  biological regulation
# A2ML1              GO:0065007  biological regulation
# A3GALT2            GO:0008152      metabolic process

# %%
biological_processes = biological_processes.merge(specific_biological_processes, how='left', left_index=True, right_index=True).rename(columns={'GO_ID':'specific_process_GO_ID', 'name':'specific_process'})
biological_processes.head()
# Out:
#         general_process_GO_ID        general_process specific_process_GO_ID  \
# gene
# A1BG               GO:0009987       cellular process             GO:0032940
# A1CF               GO:0008152      metabolic process             GO:0006807
# A2M                GO:0065007  biological regulation             GO:0050789
# A2ML1              GO:0065007  biological regulation             GO:0050789
# A3GALT2            GO:0008152      metabolic process             GO:0044238
#
#                             specific_process
# gene
# A1BG                       secretion by cell
# A1CF     nitrogen compound metabolic process
# A2M         regulation of biological process
# A2ML1       regulation of biological process
# A3GALT2            primary metabolic process

# %%
biological_processes.to_pickle('biological_processes_gene_annotation.pickle')
